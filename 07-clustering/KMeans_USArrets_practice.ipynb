# %% [markdown]
# #  Clustering: KMeans
# ## USArrets dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

# %%
from statsmodels.datasets import get_rdataset
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## Dataset
# `USArrests`, a data set in the `R` computing environment.
# We retrieve the data using `get_rdataset()`, which can fetch data from many standard `R` packages.
#
# The rows of the data set contain the 50 states, in alphabetical order.

# %%
USArrests = get_rdataset('USArrests').data
USArrests.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# rownames
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %% [markdown]
# The columns of the data set contain the four variables.

# %% [markdown]
# ## $K$-Means Clustering

# %% [markdown]
# ### Perfom the clustering

# %% [markdown]
# The goal in this section is to obtain `K` clusters.
#
# Question:
# - Is neccesary to normalize these data?
# - Complete the code to perform clustering with KMeans for  𝑘=4 and 𝑘=6 clusters.

# %%
# Kmeans K=4
# Answer: Add your own code here

kmeans4 = KMeans(n_clusters=4,
                    random_state=3,
                    n_init=20).fit(USArrests);

# %% [markdown]
# ### Visualize the results

# %% [markdown]
# Plot the data with each observation colored according to its cluster assignment by means scatter plots and include the centroids.

# %%
# Scatter plots between the variables
# Answer: Add your own code here

palette = sns.color_palette("hls", n_colors=kmeans4.n_clusters)
cluster_colors = [palette[i] for i in kmeans4.labels_]

# 1. Crear la figura UNA sola vez antes del bucle
plt.figure(figsize=(12, 12))

# Variable contador para ir asignando la posición (1, 2, 3...)
plot_counter = 1 

# Bucle doble para pares de variables
for i in range(USArrests.shape[1]):
    for j in range(i + 1, USArrests.shape[1]):
        
        # Verificamos no pasarnos de 9 gráficas (ya que es 3x3)
        if plot_counter > 9: 
            break
            
        # 2. Añadir el subplot usando el contador simple
        ax = plt.subplot(3, 3, plot_counter)
        
        # Scatter plot
        ax.scatter(USArrests.iloc[:, i], USArrests.iloc[:, j], c=cluster_colors)
        ax.set_xlabel(USArrests.columns[i])
        ax.set_ylabel(USArrests.columns[j])
        
        ax.scatter(kmeans4.cluster_centers_[:, i],
                   kmeans4.cluster_centers_[:, j],
                   marker="x",
                   s=100,
                   c="black",
                   lw=3)

        # Incrementar el contador para la siguiente vuelta
        plot_counter += 1

plt.suptitle("KMeans Clustering (K=4) on USArrests Data", fontsize=16)
# 3. Ajustar espacios para que no se monten los textos
plt.tight_layout()
# 4. Mostrar TODO al final, FUERA del bucle
plt.show()

# %%
# Normilzando los datos:
scaler = StandardScaler()
USArrests_scaled = scaler.fit_transform(USArrests)
kmeans4_scaled = KMeans(n_clusters=4,
                        random_state=3,
                        n_init=20).fit(USArrests_scaled);

# Scatter plots between the variables (scaled data)
# Answer: Add your own code here

palette_scaled = sns.color_palette("hls", n_colors=kmeans4_scaled.n_clusters)
cluster_colors_scaled = [palette_scaled[i] for i in kmeans4_scaled.labels_]

# 1. Crear la figura UNA sola vez antes del bucle
plt.figure(figsize=(12, 12))

# Variable contador para ir asignando la posición (1, 2, 3...)
plot_counter = 1 

# Bucle doble para pares de variables
for i in range(USArrests_scaled.shape[1]):
    for j in range(i + 1, USArrests_scaled.shape[1]):
        
        # Verificamos no pasarnos de 9 gráficas (ya que es 3x3)
        if plot_counter > 9: 
            break
            
        # 2. Añadir el subplot usando el contador simple
        ax = plt.subplot(3, 3, plot_counter)
        
        # Scatter plot
        ax.scatter(USArrests_scaled[:, i], USArrests_scaled[:, j], c=cluster_colors_scaled)
        ax.set_xlabel(USArrests.columns[i])
        ax.set_ylabel(USArrests.columns[j])
        ax.scatter(kmeans4_scaled.cluster_centers_[:, i],
                   kmeans4_scaled.cluster_centers_[:, j],
                   marker="x",
                   s=100,
                   c="black",
                   lw=3)
        # Incrementar el contador para la siguiente vuelta
        plot_counter += 1

plt.suptitle("KMeans Clustering (K=4) on Scaled USArrests Data", fontsize=16)
# 3. Ajustar espacios para que no se monten los textos
plt.tight_layout()

# 4. Mostrar TODO al final, FUERA del bucle
plt.show()

# %% [markdown]
# ### Repeat the Kmeans with K=6

# %%
# Kmeans K=6
# Answer: Add your own code here

kmeans6 = KMeans(n_clusters=6,
                    random_state=3,
                    n_init=20).fit(USArrests);

# %%
# Scatter plots between the variables
# Answer: Add your own code here

palette = sns.color_palette("hls", n_colors=kmeans6.n_clusters)
cluster_colors = [palette[i] for i in kmeans6.labels_]

# 1. Crear la figura UNA sola vez antes del bucle
plt.figure(figsize=(12, 12))

# Variable contador para ir asignando la posición (1, 2, 3...)
plot_counter = 1 

# Bucle doble para pares de variables
for i in range(USArrests.shape[1]):
    for j in range(i + 1, USArrests.shape[1]):
        
        # Verificamos no pasarnos de 9 gráficas (ya que es 3x3)
        if plot_counter > 9: 
            break
            
        # 2. Añadir el subplot usando el contador simple
        ax = plt.subplot(3, 3, plot_counter)
        
        # Scatter plot
        ax.scatter(USArrests.iloc[:, i], USArrests.iloc[:, j], c=cluster_colors)
        ax.set_xlabel(USArrests.columns[i])
        ax.set_ylabel(USArrests.columns[j])
        
        ax.scatter(kmeans6.cluster_centers_[:, i],
                   kmeans6.cluster_centers_[:, j],
                   marker="x",
                   s=100,
                   c="black",
                   lw=3)

        # Incrementar el contador para la siguiente vuelta
        plot_counter += 1

# 3. Ajustar espacios para que no se monten los textos
plt.tight_layout()

# 4. Mostrar TODO al final, FUERA del bucle
plt.show()

# %% [markdown]
# Normalizing the data sets

# %%
# Normilzando los datos:
scaler = StandardScaler()
USArrests_scaled = scaler.fit_transform(USArrests)
kmeans6_scaled = KMeans(n_clusters=6,
                        random_state=3,
                        n_init=20).fit(USArrests_scaled);

# Scatter plots between the variables (scaled data)
# Answer: Add your own code here

palette_scaled = sns.color_palette("hls", n_colors=kmeans6_scaled.n_clusters)
cluster_colors_scaled = [palette_scaled[i] for i in kmeans6_scaled.labels_]

# 1. Crear la figura UNA sola vez antes del bucle
plt.figure(figsize=(12, 12))

# Variable contador para ir asignando la posición (1, 2, 3...)
plot_counter = 1 

# Bucle doble para pares de variables
for i in range(USArrests_scaled.shape[1]):
    for j in range(i + 1, USArrests_scaled.shape[1]):
        
        # Verificamos no pasarnos de 9 gráficas (ya que es 3x3)
        if plot_counter > 9: 
            break
            
        # 2. Añadir el subplot usando el contador simple
        ax = plt.subplot(3, 3, plot_counter)
        
        # Scatter plot
        ax.scatter(USArrests_scaled[:, i], USArrests_scaled[:, j], c=cluster_colors_scaled)
        ax.set_xlabel(USArrests.columns[i])
        ax.set_ylabel(USArrests.columns[j])
        ax.scatter(kmeans6_scaled.cluster_centers_[:, i],
                   kmeans6_scaled.cluster_centers_[:, j],
                   marker="x",
                   s=100,
                   c="black",
                   lw=3)
        # Incrementar el contador para la siguiente vuelta
        plot_counter += 1

# 3. Ajustar espacios para que no se monten los textos
plt.tight_layout()

# 4. Mostrar TODO al final, FUERA del bucle
plt.show()

# %% [markdown]
# ### Analyze the optimal number of clusters

# %% [markdown]
# a) Based on the total within-cluster sum of squares

# %%
# Answer: Add your own code here

total_w = []
for i in range(2, 30):
    kmeans = KMeans(n_clusters=i,
                    random_state=3,
                    n_init=20).fit(USArrests_scaled)
    total_w.append(kmeans.inertia_)
    print(f'K={i}, Total within-cluster sum of squares={kmeans.inertia_}')

plt.plot(range(2, 30), total_w, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Total within-cluster sum of squares')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# K=2, Total within-cluster sum of squares=104.96163315756871
# K=3, Total within-cluster sum of squares=79.95548163171664
# K=4, Total within-cluster sum of squares=57.55425863091104
# K=5, Total within-cluster sum of squares=50.10617286461216
# K=6, Total within-cluster sum of squares=44.195451280860624
# K=7, Total within-cluster sum of squares=40.425560831512854
# K=8, Total within-cluster sum of squares=35.38578658382604
# K=9, Total within-cluster sum of squares=31.121948787336308
# K=10, Total within-cluster sum of squares=27.57177682042852
# K=11, Total within-cluster sum of squares=24.316560656810115
# K=12, Total within-cluster sum of squares=22.727757559660745
# K=13, Total within-cluster sum of squares=21.465779137962517
# K=14, Total within-cluster sum of squares=19.111785410935482
# K=15, Total within-cluster sum of squares=17.579033944355118
# K=16, Total within-cluster sum of squares=16.690662063691388
# K=17, Total within-cluster sum of squares=16.693951546572528
# ...

# %% [markdown]
# b) Based on the silhoutte method

# %%
# Answer: Add your own code here

silhouette_avgs = []
for i in range(2,30):
    kmeans = KMeans(n_clusters=i,
                    random_state=3,
                    n_init=20).fit(USArrests_scaled)
    silhouette_avg = silhouette_score(USArrests_scaled, kmeans.labels_)
    silhouette_avgs.append(silhouette_avg)

plt.plot(range(2,30), silhouette_avgs, marker='o')
plt.xlabel('Number of clusters K')
plt.ylabel('Average Silhouette Score')
plt.title('Silhouette Score vs Number of Clusters')
plt.xticks(range(2,30))
plt.grid()
plt.show()

# %% [markdown]
# ### Visualize the optimal result

# %%
def plot_ellipse(ax, cluster_data, cluster_center, label, color):
    """
    Dibuja una elipse para un cluster en el gráfico dado.
    """
    cov = np.cov(cluster_data, rowvar=False)
    pearson = cov[0, 1] / np.sqrt(cov[0, 0] * cov[1, 1])
    ellipse_radius_x = np.sqrt(1 + pearson)
    ellipse_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0), width=ellipse_radius_x * 2, height=ellipse_radius_y * 2, edgecolor=color, facecolor='none')

    scale_x = np.sqrt(cov[0, 0]) * 2
    mean_x = cluster_center[0]

    scale_y = np.sqrt(cov[1, 1]) * 2
    mean_y = cluster_center[1]

    transf = transforms.Affine2D().rotate_deg(45).scale(scale_x, scale_y).translate(mean_x, mean_y)
    ellipse.set_transform(transf + ax.transData)
    ax.add_patch(ellipse)
    ax.scatter(cluster_center[0], cluster_center[1], color=color, s=100, marker='X')
    ax.text(cluster_center[0], cluster_center[1], label, fontsize=12, ha='center', va='center', color=color)
